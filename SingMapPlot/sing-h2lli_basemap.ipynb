# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
from itertools import chain

def draw_map(m, scale=0.2):
    # draw a shaded-relief image
    m.shadedrelief(scale=scale)
    
    # lats and longs are returned as a dictionary
    lats = m.drawparallels(np.linspace(-90, 90, 13))
    lons = m.drawmeridians(np.linspace(-180, 180, 13))

    # keys contain the plt.Line2D instances
    lat_lines = chain(*(tup[1][0] for tup in lats.items()))
    lon_lines = chain(*(tup[1][0] for tup in lons.items()))
    all_lines = chain(lat_lines, lon_lines)
    
    # cycle through these lines and set the desired style
    for line in all_lines:
        line.set(linestyle='-', alpha=0.3, color='w')

# %%
m = Basemap(projection='mill', resolution='i',
            lat_0=1.3, lon_0=103,
            llcrnrlat=1.20, urcrnrlat=1.6,
            llcrnrlon=103.5, urcrnrlon=104.1,)
m.drawcoastlines()
m.fillcontinents(color='coral')
m.drawmapboundary(fill_color='aqua')
x, y = m(103.8189, 1.3521)
flora_x, flora_y = m(103.9647, 1.3571)
lli_x, lli_y= m(103.8928, 1.3207)
sem_x, sem_y = m(103.805542, 1.469780)
plt.plot(x, y, 'ok', markersize=5)
plt.text(x, y, ' Singapore', fontsize=12)
plt.plot(flora_x, flora_y, 'ok', markersize=3)
plt.text(flora_x, flora_y, ' 38 Flora Drive', fontsize=8)
plt.plot(lli_x, lli_y, 'ok', markersize=3)
plt.text(lli_x, lli_y, ' LLI', fontsize=8)
plt.plot(sem_x, sem_y, 'ok', markersize=3)
plt.text(sem_x, sem_y, ' Sembawang Tip', fontsize=8)
plt.show()

# %%
# use map with it's bounding coordinates
spore_img   = plt.imread('640px-Singapore_location_map_(main_island).svg.png')
plt.imshow(spore_img, extent=[103.557, 104.131, 1.129, 1.493], alpha=0.8)
# add axis labels
plt.ylabel("Latitude", fontsize=12)
plt.xlabel("Longitude", fontsize=12)
# set the min/max axis values - these must be the same as above
plt.ylim(1.129, 1.493)
plt.xlim(103.557, 104.131)

x, y = 103.844, 1.311
flora_x, flora_y = 103.965, 1.357
lli_x, lli_y= 103.893, 1.321
plt.plot(x, y, 'ro', markersize=5, )
plt.text(x, y, ' Singapore', fontsize=8)
plt.plot(flora_x, flora_y, 'bo', markersize=5)
plt.text(flora_x, flora_y, ' 38 Flora Drive', fontsize=8)
plt.plot(lli_x, lli_y, 'bo', markersize=5)
plt.text(lli_x, lli_y, ' Lifelong Learning Institute', fontsize=8)
plt.show()
